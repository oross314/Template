# %%
import numpy as np
import matplotlib.pyplot as plt
from bones import Model
import torch
import torch.nn as nn
from torch import optim
import pandas as pd
import pickle

# %% [markdown]
# # Purpose
# This module is designed to quickly set up and optimize a supervised neural network using 1d or 2d data with 1 truth value for each data entry. Here I will demonstrate how to use the network and show that it works on 1d and 2d data.

# %% [markdown]
# ## Intializing the model
# ### import as Model and init with Model(*args)
# #### Args:
#
#       - lins: (list of integers) the widths of the linear layers
#       - activation: the activation function to be applied after each linear layer. You can create your own (using pytorch rules) or use a pytorch one
#       - optimizer: a pytorch optimizer
#       - batch_size: (int) number of samples to be trained on at a time
#       - init_lr: (float) initial learning rate (can be decayed with lr_decay kwarg)
#       - data: (array) can be 1d or 2d data. Data should be stacked along dim = 0. i.e. if you have 20 images size 3x3, your array should have shape (20, 3, 3). It will be split into train/test automatically.
#       -truth: (array) 1d array containing truth values
#       - cost: cost function

# %% [markdown]
# ## Import some sample data, in this case various qualities of wine as data and their ratings as truth

# %%
wines = pd.read_csv('winequality-red.csv').to_numpy()
truth = wines[:, -1]
data = wines[:, :-1]

# %%
## Example using only necessary arguments
lins = [100, 10, 2]
activation = nn.PReLU()
optimizer = optim.SGD
batch_size = 128
init_lr = 5e-4
#data and truth loaded in the previous cell
cost = nn.MSELoss()


model = Model(lins, activation, optimizer, batch_size, init_lr, data, truth, cost )
# Out:
# Not saving

# %% [markdown]
# ## Once the model is loaded, we can print it's parameters using model.params()
# I will explain what all the parameters mean in due time

# %%
model.params()
# Out:
#   convolution layer sizes convolution matrix sizes ResNet linear layer sizes  \
# 2                      []                       []  False    [100, 10, 2, 1]
#
#   activation training sample size  learning rate Dropout batch size epochs  \
# 2     ReLU()                 1279         0.0005       0        128      0
#
#   derr  err
# 2    0  0.0

# %% [markdown]
# ## Run it using model.run()
# It is automatically set to print the loss every epoch and plot train/test vs truth every 3 epochs, but we can adjust that.
# The default stopping point is 100 epochs, but we can change that as well.

# %%
model.run()
# Out:
# Epoch number 0
#  Current loss 7.632450983124542
#
# Epoch number 1
#  Current loss 6.462958616442691
#
# Epoch number 2
#  Current loss 5.277869541795313
# Epoch number 3
#  Current loss 4.0427274808461116
#
# Epoch number 4
#  Current loss 2.837884689158796
#
# Epoch number 5
#  Current loss 1.8678806448711875
# Epoch number 6
#  Current loss 1.2662910147544462
#
# Epoch number 7
#  Current loss 0.9725474204304039
#
# Epoch number 8
#  Current loss 0.8278501913939122
# Epoch number 9
#  Current loss 0.7332016113953094
#
# Epoch number 10
#  Current loss 0.7550947909609982
#
# Epoch number 11
#  Current loss 0.6328031886009977
# Epoch number 12
#  Current loss 0.5982062105772239
#
# Epoch number 13
#  Current loss 0.5820595188780737
#
# Epoch number 14
#  Current loss 0.613973988894929
# Epoch number 15
#  Current loss 0.6166701126757982
#
# Epoch number 16
#  Current loss 0.5489732025818007
#
# Epoch number 17
#  Current loss 0.5365458919629018
# Epoch number 18
#  Current loss 0.6121487461745104
#
# Epoch number 19
#  Current loss 0.5304930506689148
#
# Epoch number 20
#  Current loss 0.7369077764387769
# Epoch number 21
#  Current loss 0.5843478577608587
#
# Epoch number 22
#  Current loss 0.530092572105674
#
# Epoch number 23
#  Current loss 0.5286416846351798
# Epoch number 24
#  Current loss 0.5284652789764419
#
# Epoch number 25
#  Current loss 0.5233650351318226
#
# Epoch number 26
#  Current loss 0.5317523356144092
# Epoch number 27
#  Current loss 0.6102348337529679
#
# Epoch number 28
#  Current loss 0.5226962521880593
#
# Epoch number 29
#  Current loss 0.5288291910998313
# Epoch number 30
#  Current loss 0.5354070151236741
#
# Epoch number 31
#  Current loss 0.6103622626864194
#
# Epoch number 32
#  Current loss 0.5293110631827526
# Epoch number 33
#  Current loss 0.5171763639679913
#
# Epoch number 34
#  Current loss 0.5336387017157764
#
# Epoch number 35
#  Current loss 0.5807233677773995
# Epoch number 36
#  Current loss 0.5340414587218169
#
# Epoch number 37
#  Current loss 0.6650154995729867
#
# Epoch number 38
#  Current loss 0.6228277308435872
# Epoch number 39
#  Current loss 0.5788213138703078
#
# Epoch number 40
#  Current loss 0.5521479279797188
#
# Epoch number 41
#  Current loss 0.5384957443357392
# Epoch number 42
#  Current loss 0.5165993400692379
#
# Epoch number 43
#  Current loss 0.519387350822249
#
# Epoch number 44
#  Current loss 0.5448403533480668
# Epoch number 45
#  Current loss 0.5195509993052095
#
# Epoch number 46
#  Current loss 0.5279668801625689
#
# Epoch number 47
#  Current loss 0.5571323535938968
# Epoch number 48
#  Current loss 0.5399764850857586
#
# Epoch number 49
#  Current loss 0.521671354779394
#
# Epoch number 50
#  Current loss 0.5150838583356769
# Epoch number 51
#  Current loss 0.5160705078765838
#
# Epoch number 52
#  Current loss 0.5439174164294405
#
# Epoch number 53
#  Current loss 0.5150546191399004
# Epoch number 54
#  Current loss 0.5195882908945173
#
# Epoch number 55
#  Current loss 0.525557930429408
#
# Epoch number 56
#  Current loss 0.6167564401719497
# Epoch number 57
#  Current loss 0.5182638094400763
#
# Epoch number 58
#  Current loss 0.5131297202818746
#
# Epoch number 59
#  Current loss 0.5151111408255395
# Epoch number 60
#  Current loss 0.5126608492869339
#
# Epoch number 61
#  Current loss 0.5227180194400594
#
# Epoch number 62
#  Current loss 0.5324070644089158
# Epoch number 63
#  Current loss 0.5416147184077724
#
# Epoch number 64
#  Current loss 0.5660171774971176
#
# Epoch number 65
#  Current loss 0.7056724979710273
# Epoch number 66
#  Current loss 0.5234427909717161
#
# Epoch number 67
#  Current loss 0.5146080588133559
#
# Epoch number 68
#  Current loss 0.5170424506810827
# Epoch number 69
#  Current loss 0.5326555845386194
#
# Epoch number 70
#  Current loss 0.5218229243444833
#
# Epoch number 71
#  Current loss 0.512163793659049
# Epoch number 72
#  Current loss 0.5414126120443583
#
# Epoch number 73
#  Current loss 0.5628749964823875
#
# Epoch number 74
#  Current loss 0.5136858419783314
# Epoch number 75
#  Current loss 0.6498446783565557
#
# Epoch number 76
#  Current loss 0.5106978792268322
#
# Epoch number 77
#  Current loss 0.5118143234297449
# Epoch number 78
#  Current loss 0.5121804005175851
#
# Epoch number 79
#  Current loss 0.6395875613930146
#
# Epoch number 80
#  Current loss 0.5410164571124063
# Epoch number 81
#  Current loss 0.5402559430986511
#
# Epoch number 82
#  Current loss 0.514687425560411
#
# Epoch number 83
#  Current loss 0.5122892717482417
# Epoch number 84
#  Current loss 0.5476315264984146
#
# Epoch number 85
#  Current loss 0.5141035797830114
#
# Epoch number 86
#  Current loss 0.5856559729882908
# Epoch number 87
#  Current loss 0.5126831214692414
#
# Epoch number 88
#  Current loss 0.5133455376787538
#
# Epoch number 89
#  Current loss 0.514540192835482
# Epoch number 90
#  Current loss 0.5222814957730304
#
# Epoch number 91
#  Current loss 0.5503789437786442
#
# Epoch number 92
#  Current loss 0.5267716894760774
# Epoch number 93
#  Current loss 0.5220938596975276
#
# Epoch number 94
#  Current loss 0.5190463341356223
#
# Epoch number 95
#  Current loss 0.5207886562012716
# Epoch number 96
#  Current loss 0.5170668031367429
#
# Epoch number 97
#  Current loss 0.5172829944811743
#
# Epoch number 98
#  Current loss 0.5101320818732777
# Epoch number 99
#  Current loss 0.528123798426739

# %% [markdown]
# ## if you run this again without re-initializing the model, it will pick up where you left off

# %%
model.run(max_epochs = 10)
# Out:
# Epoch number 100
#  Current loss 0.5215516082982311
#
# Epoch number 101
#  Current loss 0.514356772450719
#
# Epoch number 102
#  Current loss 0.5344676595051742
# Epoch number 103
#  Current loss 0.588674358857743
#
# Epoch number 104
#  Current loss 0.5619302770427802
#
# Epoch number 105
#  Current loss 0.6099691532899973
# Epoch number 106
#  Current loss 0.5306209315537356
#
# Epoch number 107
#  Current loss 0.5121130431616214
#
# Epoch number 108
#  Current loss 0.5226632714310429
# Epoch number 109
#  Current loss 0.5246144971703263

# %% [markdown]
# ## params will update with each epoch. You can see that err (average value of the cost function) and derr (the difference between the last and second to last loss value) now have values

# %%
model.params()
# Out:
#   convolution layer sizes convolution matrix sizes ResNet linear layer sizes  \
# 2                      []                       []  False    [100, 10, 2, 1]
#
#   activation training sample size  learning rate Dropout batch size epochs  \
# 2     ReLU()                 1279         0.0005       0        128    220
#
#     derr   err
# 2 -0.002  0.52

# %% [markdown]
# ## Now let's talk kwargs (optional arguments)

# %% [markdown]
# ### For 2d data (images) you can do convolutions.
#     - csizes: (list, default []) sizes of the convolution matrices
#     - convs: (list, default []) widths of the convolution layers
#     - (both convs and csizes must be included to do convolutions)
#     -resnet: (bool, default False) if you want to use a residual network, set resnet = True (https://arxiv.org/abs/1512.03385)

# %% [markdown]
# ### so let's load some 2d data-- the fashion MNIST set in this case, which classifies images of clothing into 10 categories.

# %%
import tensorflow as tf
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
data = np.vstack((train_images, test_images))[:10000]
truth = np.append(train_labels, test_labels)[:10000]
#I've cut off the data at 10,000 samples

# %% [markdown]
# ### note that the same model works with 1 and 2d data. I chose to make adjustments so that the model is more suitable for the data, but it would run with no changes

# %%
activation = nn.Sigmoid()
optimizer = optim.SGD
init_lr = 1e-4
lins = [1000, 100, 100, 100]
model = Model(lins, activation, optimizer, batch_size, init_lr, data, truth, cost,
             convs = [1, 2,], csizes = [3, 3,])
model.params()
# Out:
# Not saving
#   convolution layer sizes convolution matrix sizes ResNet  \
# 2                  [1, 2]                   [3, 3]  False
#
#          linear layer sizes activation training sample size  learning rate  \
# 2  [1000, 100, 100, 100, 1]     ReLU()                 8000         0.0001
#
#   Dropout batch size epochs derr  err
# 2       0        128      0    0  0.0

# %%
model.run(max_epochs = 5)
# Out:
# Epoch number 0
#  Current loss 27.320777494319294
#
# Epoch number 1
#  Current loss 26.63628264186151
#
# Epoch number 2
#  Current loss 25.967396253565663
# Epoch number 3
#  Current loss 25.311995165463784
#
# Epoch number 4
#  Current loss 24.656968898688675

# %% [markdown]
# ### You can make the learning rate dynamics
# #### And adjust it as a kwarg in model.run()
#     - lr_decay: (float, default 1) learning rate decay factor. ex. if init_lr = .7 and lr_decay = .5, after 1 update the  learning rate will be lr = .7*.5.
#     -lr_min: (float, default 1e-8) minimum learning rate applied when decaying (generally a good idea to put in ~.95)

# %%
model.run( lr = 1e-3, lr_decay = .95, lr_min = 1e-8, max_epochs = 10)
# Out:
# Epoch number 5
#  Current loss 7.924299454928807
#
# Epoch number 6
#  Current loss 3.212560418347178
#
# Epoch number 7
#  Current loss 2.8604205492724106
# Epoch number 8
#  Current loss 2.8034215788722894
#
# Epoch number 9
#  Current loss 2.7775347007915117
#
# Epoch number 10
#  Current loss 2.61489499819925
# Epoch number 11
#  Current loss 2.509713001031809
#
# Epoch number 12
#  Current loss 2.481513335605968
#
# Epoch number 13
#  Current loss 2.4524942357812005
# Epoch number 14
#  Current loss 2.4498032344001666

# %% [markdown]
# ### Saving
#     One of the key elements of this system is that you can save past runs and compare their outcomes. When you start a new run, if you use the same convolution and linear layers and activation function from a previous run you will get a warning telling you which run number it was and the parameters of that run. You can also load past runs a continue running them with the option to not save, save and update the loaded file, or save in a new location.
#     -saving: (bool, default False) If you want to save, set to true
#     - run_num: (int, default None) set to the number of a past run to load it and pick up where it left off
#     -new_tar: (bool, default False) set to True if you would like to load an old run (using run_num) but save the new results in a new file
#
#     Please do not attempt to save results from different data together
#
#     Let's try saving a run

# %%
init_lr = 1e-5
model = Model(lins, activation, optimizer, batch_size, init_lr, data, truth, cost,
             max_epochs = 20, lr_decay = .9, saving = True)
model.params()
# Out:
#   convolution layer sizes convolution matrix sizes ResNet  \
# 2                      []                       []  False
#
#          linear layer sizes activation training sample size  learning rate  \
# 2  [1000, 100, 100, 100, 1]     ReLU()                 8000        0.00001
#
#   Dropout batch size epochs derr  err
# 2       0        128      0    0  0.0

# %% [markdown]
# ## I will now let it run for a few epochs, re-initialize the model and load the weights from the previous run.

# %%
model.run(max_epochs = 5)
# Out:
# Epoch number 0
#  Current loss 4.746859925626977
#
# Epoch number 1
#  Current loss 4.081624221170215
#
# Epoch number 2
#  Current loss 3.874764315637637
# Epoch number 3
#  Current loss 3.7437827559841272
#
# Epoch number 4
#  Current loss 3.6592724173071955

# %%
model = Model(lins, activation, optimizer, batch_size, init_lr, data, truth, cost,
             max_epochs = 20, saving = True, run_num = 2)
model.params()
# Out:
# Weights from run  2  loaded.
#   convolution layer sizes convolution matrix sizes ResNet  \
# 2                      []                       []  False
#
#          linear layer sizes activation training sample size  learning rate  \
# 2  [1000, 100, 100, 100, 1]     ReLU()                 8000       0.000006
#
#   Dropout batch size epochs derr   err
# 2       0        128      9    0  3.66

# %%
model.run()
# Out:
# Epoch number 9
#  Current loss 3.578635199346521
#
# Epoch number 10
#  Current loss 3.5150076771304803
#
# Epoch number 11
#  Current loss 3.461397500423229
# Epoch number 12
#  Current loss 3.414193985746134
#
# Epoch number 13
#  Current loss 3.3724487249893773
#
# Epoch number 14
#  Current loss 3.335700835377397
# Epoch number 15
#  Current loss 3.2992221976082616
#
# Epoch number 16
#  Current loss 3.2675744542512377
#
# Epoch number 17
#  Current loss 3.236760960762965
# Epoch number 18
#  Current loss 3.2096322605593355
#
# Epoch number 19
#  Current loss 3.184679365521753
#
# Epoch number 20
#  Current loss 3.163024234258164
# Epoch number 21
#  Current loss 3.136814805309097
#
# Epoch number 22
#  Current loss 3.115776164929299
#
# Epoch number 23
#  Current loss 3.0944822743399616
# Epoch number 24
#  Current loss 3.0750715488257008
#
# Epoch number 25
#  Current loss 3.056209828025675
#
# Epoch number 26
#  Current loss 3.0387311067503946
# Epoch number 27
#  Current loss 3.022998435940226
#
# Epoch number 28
#  Current loss 3.0079104018486813

# %% [markdown]
# ## Other
#     - Early stopping: there is a detection method that will stop training if th network appears to not be improving or overfitting (it will say which)
#     -There are 3 other kwargs I have no mentioned:
#         -plot_ev: (int, default 3) how many epochs between plotting results
#         -print_ev: (int, default 1) how many epochs between printing error,
#         -train_fac: (float, default .8) fraction of the datset to be used for training
#     - some kwargs can be changed in both the model initialization and as a kwarg in model.run() (so you can change mid-run). The kwargs are 'lr', 'lr_decay', 'lr_min', 'max_epochs', 'saving', 'plot_ev', 'print_ev', and 'batch_size'.
